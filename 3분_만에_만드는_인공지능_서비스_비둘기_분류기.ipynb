# %% [markdown]
# <a href="https://colab.research.google.com/github/uovvv-lab/gugu_busters/blob/master/3%EB%B6%84_%EB%A7%8C%EC%97%90_%EB%A7%8C%EB%93%9C%EB%8A%94_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%84%9C%EB%B9%84%EC%8A%A4_%EB%B9%84%EB%91%98%EA%B8%B0_%EB%B6%84%EB%A5%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <b>3분 만에 전이 학습(Transfer Learning)을 활용한 인공지능 서비스 만들기</b>
#
# * 본 프로젝트에서는 세 가지 기능을 합쳐서 순식간에 상용 인공지능 서비스를 제작합니다.
#     1. 이미지 크롤링(image crawling) 혹은 크롤링 라이브러리
#     2. 전이 학습(transfer learning)
#     3. 웹 API 개발
# * 이 프로젝트에서 만들어 볼 것은 <b>마동석/김종국/이병헌</b> 분류기(classifier)입니다.
# * 단 <b>3분</b> 만에 인공지능 개발의 전체 과정을 진행합니다.
#     * 데이터 수집/정제
#     * 인공지능 모델 학습
#     * 학습된 모델 배포
# * 한글 폰트 설치 이후에 <b>[런타임] - [런타임 다시 시작]</b>을 수행해야 합니다.

# %%
# 한글 폰트 설치하기 (꼭! 설치가 완료되면 [런타임 다시 시작]을 누르고 다시 실행하기)
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 2s (5,644 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 필요한 라이브러리 설치하기
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# Cloning into 'bing_image_downloader'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 86 (delta 38), reused 46 (delta 16), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %% [markdown]
# #### <b>1. 이미지 크롤링을 활용한 학습 이미지 수집</b>
#
# * 수집한 이미지를 저장하기 위한 폴더를 생성하고, 필요한 함수를 정의합니다.

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 만들기
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %% [markdown]
# * <b>마동석</b> 이미지 크롤링을 진행하고 데이터셋을 구축합니다.

# %%
query = '비둘기'
downloader.download(query, limit=80,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 81 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://yt3.ggpht.com/a/AATXAJz_e3kIZt90yxVBmokPI0Bu7aMwXxcEveCa=s900-c-k-c0xffffffff-no-rj-mo)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (http://storage.enuri.info/pic_upload/knowbox/mobile_img/20190601110102001.jpeg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://yt3.ggpht.com/a/AGF-l79GTHivHOy9DTuwxRjLogrvnh-G98Bfii4iJA=s900-c-k-c0xffffffff-no-rj-mo)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://i.huffpost.com/gen/3695580/images/o-3-facebook.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://img.hani.co.kr/imgdb/resize/2018/1016/153957173102_20181016.JPG)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/2205D43D57C76FE004)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (https://static.hubzum.zumst.com/hubzum/2020/11/12/10/12f06cccae8e4b7f8012cc9525f2aa0c.jpg)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (https://i.ytimg.com/vi/Cuv3OcbgYDk/maxresdefault.jpg)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/9939CB3B5B1A4E6007)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (http://newsimg.hankookilbo.com/2019/03/19/201903190891013057_1.jpg)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (http://image.chosun.com/sitedata/image/201202/04/2012020400862_0.jpg)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (http://www.indica.or.kr/xe/files/attach/images/5746022/440/428/004/0962bb2198dcc5a08d42f0ce9876bf0c.JPG)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (http://cfile213.uf.daum.net/image/1239CB3F4FFA39741D21D7)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (http://cfile210.uf.daum.net/image/2746F14D56E8172330FF8B)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/262E0F485477DB5012)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (http://cfs10.blog.daum.net/image/1/blog/2007/09/24/19/35/46f792a715e5c)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/152337444F501D8D3D)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (https://image.ytn.co.kr/general/jpg/2018/0922/201809221029587184_t.jpg)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (http://cfile213.uf.daum.net/image/17169B174A077A4974B83C)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/2164CB4A55DC34F424)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (https://pds.joins.com/news/FbMetaImage/201903/c5692808-0939-43e3-963e-1a2518f6a1b1.jpg)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (https://img.sbs.co.kr/newimg/news/20150629/200847756_1280.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (http://kwaus.org/files/attach/images/402/878/050/c41e45650b59c4a64f7dc02109d9f837.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (https://ae01.alicdn.com/kf/HTB1bip2t29TBuNjy1zbq6xpepXae/Zilin-22-30-18-cm.jpg_640x640.jpg)
# #40 파일 다운로드가 완료되었습니다.
# #41 이미지 다운로드 (https://img.lovepik.com/element/40073/8014.png_1200.png)
# #41 파일 다운로드가 완료되었습니다.
# #42 이미지 다운로드 (https://i.ytimg.com/vi/2e9vCYu9x5o/hqdefault.jpg)
# #42 파일 다운로드가 완료되었습니다.
# #43 이미지 다운로드 (https://e7.pngegg.com/pngimages/698/851/png-clipart-pigeon-pigeon.png)
# #43 파일 다운로드가 완료되었습니다.
# #44 이미지 다운로드 (https://i.ytimg.com/vi/J_F_ScWPkmc/maxresdefault.jpg)
# #44 파일 다운로드가 완료되었습니다.
# #45 이미지 다운로드 (https://ppss.kr/wp-content/uploads/2013/04/118.jpg)
# #45 파일 다운로드가 완료되었습니다.
# #46 이미지 다운로드 (https://img.lovepik.com/element/40050/9114.png_1200.png)
# #46 파일 다운로드가 완료되었습니다.
# #47 이미지 다운로드 (https://i.ytimg.com/vi/XLkSQKCEKeE/hqdefault.jpg)
# #47 파일 다운로드가 완료되었습니다.
# #48 이미지 다운로드 (https://i.ytimg.com/vi/8n7CZUjwAjU/maxresdefault.jpg)
# #48 파일 다운로드가 완료되었습니다.
# #49 이미지 다운로드 (https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/8e/79/22/8e79227f-ef26-7d01-5c7a-ca450d224425/pr_source.png/750x750bb.jpeg)
# #49 파일 다운로드가 완료되었습니다.
# #50 이미지 다운로드 (http://cfs15.tistory.com/image/21/tistory/2008/11/23/19/18/49292dd8c237e)
# #50 파일 다운로드가 완료되었습니다.
# #51 이미지 다운로드 (http://t1.daumcdn.net/liveboard/petnu/fdd8df7649854f4693945e20faf65654.jpg)
# #51 파일 다운로드가 완료되었습니다.
# #52 이미지 다운로드 (http://cfile203.uf.daum.net/image/17570C3B50014C5534B836)
# #52 파일 다운로드가 완료되었습니다.
# #53 이미지 다운로드 (http://upload.wikimedia.org/wikipedia/commons/a/a7/Streptopelia_orientalis1.jpg)
# #53 파일 다운로드가 완료되었습니다.
# #54 이미지 다운로드 (http://www.petnu.com/wys2/file_attach/2016/07/21/1469093453-52.jpg)
# #54 파일 다운로드가 완료되었습니다.
# #55 이미지 다운로드 (https://img.lovepik.com/element/40069/5665.png_860.png)
# #55 파일 다운로드가 완료되었습니다.
# #56 이미지 다운로드 (https://image.librewiki.net/thumb/1/1d/비둘기호_객차_측면.jpg/1200px-비둘기호_객차_측면.jpg)
# [Info] Issue getting: https://image.librewiki.net/thumb/1/1d/비둘기호_객차_측면.jpg/1200px-비둘기호_객차_측면.jpg
# [Error] 'ascii' codec can't encode characters in position 16-19: ordinal not in range(128)
# #56 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/2261E54657943B0C2C)
# #56 파일 다운로드가 완료되었습니다.
# #57 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/255F334657943B0D2E)
# #57 파일 다운로드가 완료되었습니다.
# #58 이미지 다운로드 (https://i.ytimg.com/vi/_lgFVhlB4z8/maxresdefault.jpg)
# #58 파일 다운로드가 완료되었습니다.
# #59 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/250F0E4657943B0D06)
# #59 파일 다운로드가 완료되었습니다.
# #60 이미지 다운로드 (https://e7.pngegg.com/pngimages/727/249/png-clipart-pigeon-pigeon.png)
# #60 파일 다운로드가 완료되었습니다.
# #61 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99F32D355EF4648006)
# #61 파일 다운로드가 완료되었습니다.
# #62 이미지 다운로드 (http://cfile223.uf.daum.net/image/18733C044B9F8955675808)
# #62 파일 다운로드가 완료되었습니다.
# #63 이미지 다운로드 (https://img1.daumcdn.net/relay/cafe/original/?fname=http:%2F%2Fcfs4.blog.daum.net%2Fimage%2F30%2Fblog%2F2007%2F07%2F08%2F10%2F54%2F469043d403b48%26filename%3D비둘기.jpg)
# [Info] Issue getting: https://img1.daumcdn.net/relay/cafe/original/?fname=http:%2F%2Fcfs4.blog.daum.net%2Fimage%2F30%2Fblog%2F2007%2F07%2F08%2F10%2F54%2F469043d403b48%26filename%3D비둘기.jpg
# [Error] 'ascii' codec can't encode characters in position 138-140: ordinal not in range(128)
# #63 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbdE5sR%2Fbtqx8AviHCz%2F1fFK9zAQin8rOtkabtPQyK%2Fimg.jpg)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbdE5sR%2Fbtqx8AviHCz%2F1fFK9zAQin8rOtkabtPQyK%2Fimg.jpg
# [Error] HTTP Error 403: Forbidden
# #63 이미지 다운로드 (http://newsimg.hankookilbo.com/2016/07/12/201607121735926291_1.jpg)
# #63 파일 다운로드가 완료되었습니다.
# #64 이미지 다운로드 (http://fimg2.pann.com/new/download.jsp?FileID=22995961)
# #64 파일 다운로드가 완료되었습니다.
# #65 이미지 다운로드 (http://photo-media.hanmail.net/200710/19/donga/20071019065010.214.0.jpg)
# #65 파일 다운로드가 완료되었습니다.
# #66 이미지 다운로드 (http://cfile218.uf.daum.net/image/9949884A5BC85AE634D587)
# #66 파일 다운로드가 완료되었습니다.
# #67 이미지 다운로드 (http://www.gif.ovh/korean-gif/비둘기 Gif 2/비둘기 Gif (1).gif)
# [Info] Issue getting: http://www.gif.ovh/korean-gif/비둘기 Gif 2/비둘기 Gif (1).gif
# [Error] URL can't contain control characters. '/korean-gif/비둘기 Gif 2/비둘기 Gif (1).gif' (found at least ' ')

#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 학습을 위해 필요한 라이브러리를 불러옵니다.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device 객체

# %% [markdown]
# * 데이터셋을 불러옵니다.

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './custom_dataset'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('학습 데이터셋 크기:', len(train_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:', class_names)
# Out:
# 학습 데이터셋 크기: 30
# 테스트 데이터셋 크기: 50
# 클래스: ['비둘기']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# * 간단히 이미지를 시각화해 봅시다.

# %%
import matplotlib.pyplot as plt

def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# * 학습할 CNN 딥러닝 모델 객체를 초기화합니다.

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# HBox(children=(FloatProgress(value=0.0, max=87319819.0), HTML(value='')))

# %% [markdown]
# * 학습을 진행합니다.

# %%
num_epochs = 50
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [예측 결과: 비둘기] (실제 정답: 비둘기)
# [Test Phase] Loss: 0.0002 Acc: 100.0000% Time: 3.3663s

# %% [markdown]
# #### <b>3. 분류 모델 API 개발</b>
#
# * 학습된 분류 모델을 다른 사람이 사용할 수 있도록 API를 개발하여 배포합니다.
# * 먼저 한 장의 이미지를 파일로부터 읽어와 분류 결과를 반환하는 기능을 작성합니다.

# %%
# 테스트용 이미지 다운로드하기
# !wget https://upload.wikimedia.org/wikipedia/commons/f/f1/Don_Lee_by_Gage_Skidmore.jpg -O test_image.jpg
# Out:
# --2021-07-07 00:20:56--  https://upload.wikimedia.org/wikipedia/commons/f/f1/Don_Lee_by_Gage_Skidmore.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4070584 (3.9M) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]   3.88M  18.6MB/s    in 0.2s
#
# 2021-07-07 00:20:56 (18.6 MB/s) - ‘test_image.jpg’ saved [4070584/4070584]

# %%
from PIL import Image


image = Image.open('test_image.jpg')
image = transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image)
    _, preds = torch.max(outputs, 1)
    imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46168 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# * 웹 API 개방을 위해 <b>Ngrok</b> 서비스를 이용합니다.
# * API 기능 제공을 위해 <b>Flask 프레임워크</b>를 사용합니다.

# %% [markdown]
# * API를 개방할 수 있으며 실행할 때마다 서버의 주소가 변경됩니다.
# * 서버 주소를 정확히 확인할 필요가 있습니다.
